# %%
#!pip install scispacy
#model: en_ner_bionlp13cg_md
#!pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_ner_bionlp13cg_md-0.5.4.tar.gz

# %% [markdown]
# ### Tutorials
# https://medium.com/@ndubisiprecious/clinical-biomedical-named-entity-recognition-nlp-using-scispacy-80fcfa1cf648

# %%
import scispacy
import spacy

# %%
#set the gpu flag
spacy.prefer_gpu()

# %%
text = """
The AHR Receptor
The aryl hydrocarbon receptor (AHR) is a ligand-activated transcription factor that belongs to the basic helix-loop-helix Per-ARNT-Sim (bHLH-PAS) superfamily and consists of three domains: the DNA-binding domain (DBD), ligand binding domain (LBD) and transactivation domain (TAD)[1]. Other members of this superfamily include the AHR nuclear translocator (ARNT), which acts as a dimerization partner of the AHR [2][3]; Per, a circadian transcription factor; and Sim, the “single-minded” protein involved in neuronal development [4][5]. This group of proteins shares a highly conserved PAS domain and is involved in the detection of and adaptation to environmental change[4].

Investigations of invertebrates possessing early homologs of the AhR suggest that the AhR evolutionarily functioned in regulation of the cell cycle, cellular proliferation and differentiation, and cell-to-cell communications (Hahn et al 2002). However, critical functions in angiogenesis, regulation of the immune system, neuronal processes, metabolism, development of the heart and other organ systems, and detoxification have emerged sometime in early vertebrate evolution (Duncan et al., 1998; Emmons et al., 1999; Lahvis and Bradfield, 1998).

The molecular Initiating Event

Figure 1: The molecular mechanism of activation of gene expression by AHR.
 
The molecular mechanism for AHR-mediated activation of gene expression is presented in Figure 1. In its unliganded form, the AHR is part of a cytosolic complex containing heat shock protein 90 (HSP90), the HSP90 co-chaperone p23 and AHR-interacting protein (AIP)[6]. Upon ligand binding, the AHR migrates to the nucleus where it dissociates from the cytosolic complex and forms a heterodimer with ARNT[7]. The AHR-ARNT complex then binds to a xenobiotic response element (XRE) found in the promoter of an AHR-regulated gene and recruits co-regulators such as CREB binding protein/p300, steroid receptor co-activator (SRC) 1, SRC-2, SRC-3 and nuclear receptor interacting protein 1, leading to induction or repression of gene expression[6]. Expression levels of several genes, including phase I (e.g. cytochrome P450 (CYP) 1A, CYP1B, CYP2A) and phase II enzymes (e.g. uridine diphosphate glucuronosyl transferase (UDP-GT), glutathione S-transferases (GSTs)), as well as genes involved in cell proliferation (transforming growth factor-beta, interleukin-1 beta), cell cycle regulation (p27, jun-B) and apoptosis (Bax), are regulated through this mechanism [6][8][7][9].

AHR Isoforms
Over time the AhR has undergone gene duplication and diversification in vertebrates, which has resulted in multiple clades of AhR, namely AhR1, AhR2, and AhR3 (Hahn 2002).
Fishes and birds express AhR1s and AhR2s, while mammals express a single AhR that is homologous to the AhR1 (Hahn 2002; Hahn et al 2006).
The AhR3 is poorly understood and known only from some cartilaginous fishes (Hahn 2002).
Little is known about diversity of AhRs in reptiles and amphibians (Hahn et al 2002).
In some taxa, subsequent genome duplication events have further led to multiple isoforms of AhRs in some species, with up to four isoforms of the AhR (α, β, δ, γ) having been identified in Atlantic salmon (Salmo salar) (Hansson et al 2004).
Although homologs of the AhR have been identified in some invertebrates, compared to vertebrates these AhRs have differences in binding of ligands in the species investigated to date (Hahn 2002; Hahn et al 1994).
Roles of isoforms in birds:

Two AHR isoforms (AHR1 and AHR2) have been identified in the black-footed albatross (Phoebastria nigripes), great cormorant (Phalacrocorax carbo) and domestic chicken (Gallus gallus domesticus)[10]. AHR1 mRNA levels were similar in the kidney, heart, lung, spleen, brain, gonad and intestine from the great cormorant but were lower in muscle and pancreas. AHR2 expression was mainly observed in the liver, but was also detected in gonad, brain and intestine. AHR1 levels represented a greater proportion (80%) of total AHR levels than AHR2 in the cormorant liver[10], and while both AHR isoforms bound to TCDD, AHR2 was less effective at inducing TCDD-dependent transactivation compared to AHR1 in black-footed albatross, great cormorant and domestic chicken[11][10].

AhR1 and AhR2 both bind and are activated by TCDD in vitro (Yasui et al 2007).
AhR1 has greater binding affinity and sensitivity to activation by TCDD relative to AhR2 (Yasui et al 2007).
AhR1 is believed to mediate toxicities of DLCs, while AhR2 has no known role in toxicities (Farmahin et al 2012; Farmahin et al 2013; Manning et al 2012).
Roles of isoforms in fishes:

AhR1 and AhR2 both bind and are activated by TCDD in vitro (Bak et al 2013; Doering et al 2014; 2015; Karchner et al 1999; 2005).
AhR1 has greater sensitivity to activation by TCDD than AhR2 in red seabream (Pagrus major), white sturgeon (Acipenser transmontanus), and lake sturgeon (Acipenser fulvescens) (Bak et al 2013; Doering et al 2014; 2015)
AhR2 has greater binding affinity or activation by TCDD than AhR1 in zebrafish (Danio rerio) and mummichog (Fundulus heteroclitus) (Karchner et al 1999; 2005).
AhR2 is believed to mediate toxicities in fishes, while AhR1 has no known role in toxicities. Specifically, knockdown of AhR2 protects against toxicities of dioxin-like compounds (DLCs) and polycyclic aromatic hydrocarbons (PAHs) in zebrafish (Danio rerio) and mummichog (Fundulus heteroclitus), while knockdown of AhR1 offers no protection (Clark et al 2010; Prasch et al 2003; Van Tiem & Di Giulio 2011).
Roles of isoforms in amphibians and reptiles:

Less is known about AhRs of amphibians or reptiles.
AhR1 is believed to mediate toxicities in amphibians (Hahn 2002; Lavine et al 2005; Oka et al 2016; Shoots et al 2015). However, all AhRs of amphibians that have been investigated have very low affinity for TCDD (Hahn 2002; Lavine et al 2005; Oka et al 2016; Shoots et al 2015).
Both AhR1s and AhR2 of American alligator (Alligator mississippiensis) are activated by agonists with comparable sensitivities (Oka et al 2016). AhRs of no other reptiles have been investigated.
Role in mammals

AhR expression is essentially ubiquitous in mammals consistent with a broad-spectrum homeostatic role, however expression levels varying widely across tissues with the liver, thymus, lung, kidney, spleen, and placenta exhibiting greatest expression (Harper PA). Additionally, AhR expression is developmentally regulated, and more recent evidence indicates a role for the AhR in developmental process affecting hematopoiesis, immune system biology, neural differentiation, and liver architecture (Wright E J) . AHR is involved in regulating the rate of apoptosis of oocytes in germ cell nests during embryonic life and in regulating survival of oocytes in the fetal and neonatal ovary. Specifically, studies have shown that ovaries obtained from AHRKO mice on ED13.5 and cultured for 72 h in the absence of hormonal support with the aim of inducing apoptosis, contained higher numbers of non-apoptotic germ cells compared to wild-type (WT) ovaries cultured in the same conditions (Hernández-Ochoa)
"""

text = text.replace('\n', '')

# %%
text[0:1000]
# Out:
# 'The AHR ReceptorThe aryl hydrocarbon receptor (AHR) is a ligand-activated transcription factor that belongs to the basic helix-loop-helix Per-ARNT-Sim (bHLH-PAS) superfamily and consists of three domains: the DNA-binding domain (DBD), ligand binding domain (LBD) and transactivation domain (TAD)[1]. Other members of this superfamily include the AHR nuclear translocator (ARNT), which acts as a dimerization partner of the AHR [2][3]; Per, a circadian transcription factor; and Sim, the “single-minded” protein involved in neuronal development [4][5]. This group of proteins shares a highly conserved PAS domain and is involved in the detection of and adaptation to environmental change[4].Investigations of invertebrates possessing early homologs of the AhR suggest that the AhR evolutionarily functioned in regulation of the cell cycle, cellular proliferation and differentiation, and cell-to-cell communications (Hahn et al 2002). However, critical functions in angiogenesis, regulation of the imm'

# %%
nlp = spacy.load("en_ner_bionlp13cg_md")
# Out:
# Running cells with 'Python 3.13.7' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/arup/AppData/Local/Programs/Python/Python313/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
# # Add abbreviation detector by its factory name
# nlp.add_pipe("abbreviation_detector")

# # Add entity linker by its factory name with config
# nlp.add_pipe("scispacy_entity_linker", config={"resolve_abbreviations": True, "name": "mesh"})

# %%
# from scispacy.abbreviation import AbbreviationDetector
# from scispacy.linking import EntityLinker

# #Add mesh terms
# abbreviation_pipe = AbbreviationDetector(nlp)
# nlp.add_pipe(abbreviation_pipe)
# linker = EntityLinker(resolve_abbreviations=True, name="mesh")
# nlp.add_pipe(linker)

# %%
from spacy import displacy

# %%
col_dict = {}
s_colours = ['#e6194B', '#3cb44b', '#ffe119', '#ffd8b1', '#f58231', '#f032e6', '#42d4f4']
for label, colour in zip(nlp.pipe_labels['ner'], s_colours):
    col_dict[label] = colour

options = {'ents': nlp.pipe_labels['ner'], 'colors':col_dict}

# %%
doc= nlp(text)

#print all the entity
for ent in doc.ents:
    #print(f"Text: {ent.text}, Entity Type: {ent.label_}")
    print(f"Text: {ent.text}, Start: {ent.start_char}, End: {ent.end_char}, Entity Type: {ent.label_}")
# Out:
# Text: AHR, Start: 47, End: 50, Entity Type: GENE_OR_GENE_PRODUCT
# Text: DBD, Start: 229, End: 232, Entity Type: CELLULAR_COMPONENT
# Text: LBD, Start: 258, End: 261, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AHR nuclear, Start: 346, End: 357, Entity Type: GENE_OR_GENE_PRODUCT
# Text: ARNT, Start: 372, End: 376, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AHR, Start: 423, End: 426, Entity Type: GENE_OR_GENE_PRODUCT
# Text: Per, Start: 435, End: 438, Entity Type: GENE_OR_GENE_PRODUCT
# Text: Sim, Start: 478, End: 481, Entity Type: GENE_OR_GENE_PRODUCT
# Text: single-minded, Start: 488, End: 501, Entity Type: GENE_OR_GENE_PRODUCT
# Text: neuronal, Start: 523, End: 531, Entity Type: CELL
# Text: PAS, Start: 601, End: 604, Entity Type: SIMPLE_CHEMICAL
# Text: AhR, Start: 755, End: 758, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR, Start: 776, End: 779, Entity Type: GENE_OR_GENE_PRODUCT
# Text: cell, Start: 827, End: 831, Entity Type: CELL
# Text: cellular, Start: 839, End: 847, Entity Type: CELL
# Text: cell-to-cell, Start: 887, End: 899, Entity Type: CELL
# Text: neuronal, Start: 1012, End: 1020, Entity Type: CELL
# Text: heart, Start: 1063, End: 1068, Entity Type: ORGAN
# Text: organ, Start: 1079, End: 1084, Entity Type: ORGAN
# Text: Lahvis, Start: 1208, End: 1214, Entity Type: CELLULAR_COMPONENT
# Text: AHR, Start: 1465, End: 1468, Entity Type: GENE_OR_GENE_PRODUCT
# Text: HSP90, Start: 1534, End: 1539, Entity Type: GENE_OR_GENE_PRODUCT
# Text: HSP90 co-chaperone, Start: 1546, End: 1564, Entity Type: GENE_OR_GENE_PRODUCT
# Text: p23, Start: 1565, End: 1568, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AHR, Start: 1632, End: 1635, Entity Type: GENE_OR_GENE_PRODUCT
# Text: nucleus, Start: 1652, End: 1659, Entity Type: CELLULAR_COMPONENT
# Text: AHR-ARNT, Start: 1750, End: 1758, Entity Type: SIMPLE_CHEMICAL
# Text: AHR-regulated, Start: 1845, End: 1858, Entity Type: GENE_OR_GENE_PRODUCT
# Text: CREB binding protein/p300, steroid receptor co-activator, Start: 1899, End: 1955, Entity Type: GENE_OR_GENE_PRODUCT
# Text: SRC-2, Start: 1965, End: 1970, Entity Type: GENE_OR_GENE_PRODUCT
# Text: SRC-3, Start: 1972, End: 1977, Entity Type: GENE_OR_GENE_PRODUCT
# Text: nuclear receptor interacting protein 1, Start: 1982, End: 2020, Entity Type: GENE_OR_GENE_PRODUCT
# Text: cytochrome P450, Start: 2140, End: 2155, Entity Type: GENE_OR_GENE_PRODUCT
# Text: CYP1B, Start: 2166, End: 2171, Entity Type: GENE_OR_GENE_PRODUCT
# Text: CYP2A, Start: 2173, End: 2178, Entity Type: GENE_OR_GENE_PRODUCT
# Text: phase II enzymes, Start: 2184, End: 2200, Entity Type: GENE_OR_GENE_PRODUCT
# Text: uridine diphosphate glucuronosyl transferase, Start: 2207, End: 2251, Entity Type: SIMPLE_CHEMICAL
# Text: glutathione S-transferases, Start: 2262, End: 2288, Entity Type: GENE_OR_GENE_PRODUCT
# Text: GSTs, Start: 2290, End: 2294, Entity Type: GENE_OR_GENE_PRODUCT
# Text: cell, Start: 2327, End: 2331, Entity Type: CELL
# Text: transforming growth factor-beta, Start: 2347, End: 2378, Entity Type: GENE_OR_GENE_PRODUCT
# Text: interleukin-1 beta, Start: 2380, End: 2398, Entity Type: GENE_OR_GENE_PRODUCT
# Text: cell, Start: 2401, End: 2405, Entity Type: CELL
# Text: p27, Start: 2424, End: 2427, Entity Type: GENE_OR_GENE_PRODUCT
# Text: jun-B, Start: 2429, End: 2434, Entity Type: GENE_OR_GENE_PRODUCT
# Text: Bax, Start: 2451, End: 2454, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR, Start: 2533, End: 2536, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR, Start: 2645, End: 2648, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR1, Start: 2657, End: 2661, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR2, Start: 2663, End: 2667, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR3, Start: 2673, End: 2677, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR1s, Start: 2715, End: 2720, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR, Start: 2763, End: 2766, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR1, Start: 2793, End: 2797, Entity Type: GENE_OR_GENE_PRODUCT
# Text: cartilaginous fishes, Start: 2882, End: 2902, Entity Type: PATHOLOGICAL_FORMATION
# Text: AhRs, Start: 2950, End: 2954, Entity Type: GENE_OR_GENE_PRODUCT
# Text: reptiles, Start: 2958, End: 2966, Entity Type: ORGANISM
# Text: amphibians (Hahn et al 2002).In, Start: 2971, End: 3002, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhRs, Start: 3092, End: 3096, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR, Start: 3146, End: 3149, Entity Type: GENE_OR_GENE_PRODUCT
# Text: Salmo salar, Start: 3206, End: 3217, Entity Type: ORGANISM
# Text: AhR, Start: 3265, End: 3268, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhRs, Start: 3343, End: 3347, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AHR, Start: 3483, End: 3486, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AHR1, Start: 3497, End: 3501, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AHR2, Start: 3506, End: 3510, Entity Type: GENE_OR_GENE_PRODUCT
# Text: Phoebastria nigripes, Start: 3564, End: 3584, Entity Type: ORGANISM
# Text: Phalacrocorax carbo, Start: 3604, End: 3623, Entity Type: ORGANISM
# Text: chicken, Start: 3638, End: 3645, Entity Type: ORGANISM
# Text: Gallus gallus domesticus)[10, Start: 3647, End: 3675, Entity Type: ORGANISM
# Text: AHR1, Start: 3678, End: 3682, Entity Type: GENE_OR_GENE_PRODUCT
# Text: kidney, Start: 3715, End: 3721, Entity Type: ORGAN
# Text: heart, Start: 3723, End: 3728, Entity Type: ORGAN
# Text: lung, Start: 3730, End: 3734, Entity Type: ORGAN
# Text: spleen, Start: 3736, End: 3742, Entity Type: ORGAN
# Text: brain, Start: 3744, End: 3749, Entity Type: ORGAN
# Text: gonad, Start: 3751, End: 3756, Entity Type: TISSUE
# Text: intestine, Start: 3761, End: 3770, Entity Type: ORGAN
# Text: muscle, Start: 3814, End: 3820, Entity Type: ORGAN
# Text: pancreas, Start: 3825, End: 3833, Entity Type: ORGAN
# Text: AHR2, Start: 3835, End: 3839, Entity Type: GENE_OR_GENE_PRODUCT
# Text: liver, Start: 3878, End: 3883, Entity Type: ORGAN
# Text: gonad, Start: 3910, End: 3915, Entity Type: CANCER
# Text: brain, Start: 3917, End: 3922, Entity Type: ORGAN
# Text: intestine, Start: 3927, End: 3936, Entity Type: ORGAN
# Text: AHR1, Start: 3938, End: 3942, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AHR, Start: 3998, End: 4001, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AHR2, Start: 4014, End: 4018, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AHR, Start: 4062, End: 4065, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AHR2, Start: 4090, End: 4094, Entity Type: GENE_OR_GENE_PRODUCT
# Text: TCDD-dependent, Start: 4126, End: 4140, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AHR1, Start: 4169, End: 4173, Entity Type: GENE_OR_GENE_PRODUCT
# Text: black-footed, Start: 4177, End: 4189, Entity Type: ORGANISM
# Text: AhR2, Start: 4255, End: 4259, Entity Type: GENE_OR_GENE_PRODUCT
# Text: TCDD, Start: 4391, End: 4395, Entity Type: SIMPLE_CHEMICAL
# Text: AhR2, Start: 4408, End: 4412, Entity Type: GENE_OR_GENE_PRODUCT
# Text: DLCs, Start: 4474, End: 4478, Entity Type: SIMPLE_CHEMICAL
# Text: AhR2, Start: 4486, End: 4490, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR1, Start: 4614, End: 4618, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR2, Start: 4623, End: 4627, Entity Type: GENE_OR_GENE_PRODUCT
# Text: Bak, Start: 4674, End: 4677, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR2, Start: 4799, End: 4803, Entity Type: GENE_OR_GENE_PRODUCT
# Text: Pagrus, Start: 4821, End: 4827, Entity Type: TISSUE
# Text: Acipenser transmontanus, Start: 4852, End: 4875, Entity Type: ORGANISM
# Text: Acipenser fulvescens, Start: 4897, End: 4917, Entity Type: ORGANISM
# Text: Bak, Start: 4920, End: 4923, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR1, Start: 5022, End: 5026, Entity Type: GENE_OR_GENE_PRODUCT
# Text: zebrafish, Start: 5030, End: 5039, Entity Type: ORGANISM
# Text: Danio rerio, Start: 5041, End: 5052, Entity Type: ORGANISM
# Text: AhR1, Start: 5176, End: 5180, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR2, Start: 5241, End: 5245, Entity Type: GENE_OR_GENE_PRODUCT
# Text: zebrafish (Danio rerio, Start: 5353, End: 5375, Entity Type: ORGANISM
# Text: AhR1, Start: 5435, End: 5439, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhRs, Start: 5591, End: 5595, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR1, Start: 5622, End: 5626, Entity Type: GENE_OR_GENE_PRODUCT
# Text: Shoots, Start: 5722, End: 5728, Entity Type: CELL
# Text: AhRs, Start: 5755, End: 5759, Entity Type: GENE_OR_GENE_PRODUCT
# Text: amphibians, Start: 5763, End: 5773, Entity Type: ORGANISM
# Text: Shoots, Start: 5881, End: 5887, Entity Type: CELL
# Text: AhR2, Start: 5915, End: 5919, Entity Type: GENE_OR_GENE_PRODUCT
# Text: broad-spectrum, Start: 6179, End: 6193, Entity Type: SIMPLE_CHEMICAL
# Text: tissues, Start: 6260, End: 6267, Entity Type: TISSUE
# Text: liver, Start: 6277, End: 6282, Entity Type: ORGAN
# Text: thymus, Start: 6284, End: 6290, Entity Type: ORGAN
# Text: lung, Start: 6292, End: 6296, Entity Type: ORGAN
# Text: kidney, Start: 6298, End: 6304, Entity Type: ORGAN
# Text: spleen, Start: 6306, End: 6312, Entity Type: ORGAN
# Text: placenta, Start: 6318, End: 6326, Entity Type: ORGAN
# Text: PA, Start: 6366, End: 6368, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR, Start: 6385, End: 6388, Entity Type: GENE_OR_GENE_PRODUCT
# Text: AhR, Start: 6480, End: 6483, Entity Type: GENE_OR_GENE_PRODUCT
# Text: neural, Start: 6557, End: 6563, Entity Type: TISSUE
# Text: liver, Start: 6585, End: 6590, Entity Type: ORGAN
# Text: AHR, Start: 6619, End: 6622, Entity Type: GENE_OR_GENE_PRODUCT
# Text: germ cell, Start: 6685, End: 6694, Entity Type: CANCER
# Text: fetal, Start: 6768, End: 6773, Entity Type: ANATOMICAL_SYSTEM
# Text: ovary, Start: 6787, End: 6792, Entity Type: ORGAN
# Text: ovaries, Start: 6832, End: 6839, Entity Type: ORGAN
# Text: AHRKO mice, Start: 6854, End: 6864, Entity Type: CANCER
# Text: ED13.5, Start: 6868, End: 6874, Entity Type: GENE_OR_GENE_PRODUCT
# Text: germ cells, Start: 7010, End: 7020, Entity Type: CELL
# Text: ovaries, Start: 7048, End: 7055, Entity Type: ORGAN

# %%
# Create distict colours for labels
col_dict = {}
s_colours = ['#e6194B', '#3cb44b', '#ffe119', '#ffd8b1', '#f58231', '#f032e6', '#42d4f4']
for label, colour in zip(nlp.pipe_labels['ner'], s_colours):
    col_dict[label] = colour

options = {'ents': nlp.pipe_labels['ner'], 'colors':col_dict}
spacy.displacy.render(doc, style = 'ent', jupyter = True, options = options)

#[(ent.text, ent.label_) for ent in doc.ents]
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The AHR ReceptorThe aryl hydrocarbon receptor (
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AHR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
# ) is a ligand-activated transcription factor that belongs to the basic helix-loop-helix Per-ARNT-Sim (bHLH-PAS) superfamily and consists of three domains: the DNA-binding domain (
# <mark class="entity" style="background: #f58231; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DBD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CELLULAR_COMPONENT</span>
# </mark>
# ), ligand binding domain (
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LBD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
# ) and transactivation domain (TAD)[1]. Other members of this superfamily include the
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AHR nuclear
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
#  translocator (
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ARNT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
# ), which acts as a dimerization partner of the
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AHR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
#  [2][3];
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Per
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
# , a circadian transcription factor; and
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sim
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
# , the “
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     single-minded
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
# ” protein involved in
# <mark class="entity" style="background: #ffd8b1; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     neuronal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CELL</span>
# </mark>
#  development [4][5]. This group of proteins shares a highly conserved
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PAS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIMPLE_CHEMICAL</span>
# </mark>
#  domain and is involved in the detection of and adaptation to environmental change[4].Investigations of invertebrates possessing early homologs of the
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AhR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
#  suggest that the
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AhR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
#  evolutionarily functioned in regulation of the
# <mark class="entity" style="background: #ffd8b1; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cell
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CELL</span>
# </mark>
#  cycle,
# <mark class="entity" style="background: #ffd8b1; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cellular
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CELL</span>
# </mark>
#  proliferation and differentiation, and
# <mark class="entity" style="background: #ffd8b1; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cell-to-cell
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CELL</span>
# </mark>
#  communications (Hahn et al 2002). However, critical functions in angiogenesis, regulation of the immune system,
# <mark class="entity" style="background: #ffd8b1; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     neuronal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CELL</span>
# </mark>
#  processes, metabolism, development of the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     heart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORGAN</span>
# </mark>
#  and other
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     organ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORGAN</span>
# </mark>
#  systems, and detoxification have emerged sometime in early vertebrate evolution (Duncan et al., 1998; Emmons et al., 1999;
# <mark class="entity" style="background: #f58231; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lahvis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CELLULAR_COMPONENT</span>
# </mark>
#  and Bradfield, 1998).The molecular Initiating EventFigure 1: The molecular mechanism of activation of gene expression by AHR.The molecular mechanism for AHR-mediated activation of gene expression is presented in Figure 1. In its unliganded form, the
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AHR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
#  is part of a cytosolic complex conta
