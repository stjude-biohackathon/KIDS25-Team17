# %%
# conda env:  /mnt/scratch2/Maggie/miniconda3/envs/scispacy
import scispacy
import spacy
import pandas as pd
import numpy as np
from collections import defaultdict

# get webscraping output
geo = pd.read_csv('geo_webscrap.csv')

# %%
# load spacy models
ner_bio = spacy.load("en_ner_bionlp13cg_md")
ner_bc5 = spacy.load('en_ner_bc5cdr_md')
ner_jnl = spacy.load('en_ner_jnlpba_md')

models = [ner_bio, ner_bc5, ner_jnl]
# Out:
# /mnt/scratch2/Maggie/miniconda3/envs/scispacy/lib/python3.9/site-packages/spacy/language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]

# %%
# add new columns to geo file
new_geo = geo.copy(deep=True)

# minimum score for label assignment to be added to geo
threshold = 0.5

for i in range(geo.shape[0]):
    # get Summary and Overall Design as text
    text = [geo['Summary'][i], geo['Overall design'][i]]
    text = " ".join(text)

    # iterate over all available models
    for model in models:
        doc = model(text)
        beams = model.get_pipe('ner').beam_parse([ doc ], beam_width = 16, beam_density = 0.0001)
        entity_scores = defaultdict(float)
        
        for beam in beams:
            for score, ents in model.get_pipe('ner').moves.get_beam_parses(beam):
                for start, end, label in ents:
                    entity_scores[(start, end, label)] += score
    
        for key in entity_scores:
            start, end, label = key
            score = entity_scores[key]
            ent_text = str(doc[start:end])
            
            if (score > threshold):
                if label in new_geo.columns and new_geo.loc[i, label] not in ['nan', 'na']:
                    if ent_text not in new_geo.loc[i, label]:
                        new_geo.loc[i, label].append(ent_text)
                else:
                    new_geo.loc[i, label] = [ent_text]
            

# convert 'nan' and 'na' to np.nan to match existing columns
new_geo = new_geo.mask(new_geo == 'nan')
new_geo = new_geo.mask(new_geo == 'na')

# %%
new_geo
# Out:
#                                                  Title  \
# 0    Characterizing the molecular spatial and tempo...
# 1    Agilent-013282 array CGH on NCI-60 cancer cell...
# 2    Microbial community structure and functions ar...
# 3    Transcriptional profiling of lung tumour cell ...
# 4    Transcriptional profiling of lung tumour cell ...
# ..                                                 ...
# 231  Spatial control of m6A deposition on enhancer ...
# 232  Spatial control of m6A deposition on enhancer ...
# 233  Spatial control of m6A deposition on enhancer ...
# 234  DDX54 downregulation enhances anti-PD1 therapy...
# 235  KRAS G12C inhibition combined with CD47 and im...
#
#                                                Summary  \
# 0    Gene expression alterations in response to cig...
# 1    The NCI-60 cancer cell lines have been used fo...
# 2    Despite the global importance of forests, it i...
# 3    Microarray expression data generated to determ...
# 4    Microarray expression data generated to determ...
# ..                                                 ...
# 231  Interaction between the m6A methyltransferase ...
# 232  Interaction between the m6A methyltransferase ...
# 233  Interaction between the m6A methyltransferase ...
# 234  High tumor mutational burden (TMB) is a predic...
# 235  Although KRAS G12C inhibitors have altered the...
#
#                                         Overall design      Contact name  \
# 0    Bronchial brushings and biopsies were obtained...      Humam Kadara
# 1    60 cell lines (including PR:DU145 and its drug...      Sudhir Varma
# 2    12 samples were collected from two long-term p...     Hamed Azarbad
# 3    Murine tumour cell lines were isolated from in...         Emma Kerr
# 4    Murine tumour cell lines were isolated from in...         Emma Kerr
# ..                                                 ...               ...
# 231  Chromatin-associated RNA m6A profiles of METTL...         meijun ye
# 232  The mRNA expression profile of METTL3-WT or ME...         meijun ye
# 233  CUT&Tag in METTL3-WT or METTL3-3KR A549 cells ...         meijun ye
# 234  This study employs a syngeneic mouse model of ...  Jeong-Ryeol Gong
# 235  LLC Nras KO syngeneic lung tumors were treated...     Hiromichi Ebi
#
#                                  Organization name        City  \
# 0    University of Texas MD Anderson Cancer Center     Houston
# 1                                 HiThru Analytics   Princeton
# 2                          Jagiellonian University      Krakow
# 3                       Queen's University Belfast     Belfast
# 4                       Queen's University Belfast     Belfast
# ..                                             ...         ...
# 231                         SUN YAT-SEN UNIVERSITY   GuangZhou
# 232                         SUN YAT-SEN UNIVERSITY   GuangZhou
# 233                         SUN YAT-SEN UNIVERSITY   GuangZhou
# 234                                          KAIST  Yuseong-gu
# 235         Aichi Cancer Center Research Institute      Nagoya
#
#           State/province         Country Platforms  Samples  ...  \
# 0                     TX             USA   GPL6244      391  ...
# 1                     NJ             USA  GPL11068      129  ...
# 2                    NaN          Poland  GPL18982       12  ...
# 3                    NaN  United Kingdom  GPL17543       72  ...
# 4                    NaN  United Kingdom  GPL17543       72  ...
# ..                   ...             ...       ...      ...  ...
# 231  -- Please Select --           China  GPL30209        6  ...
# 232  -- Please Select --           China  GPL30209        6  ...
# 233  -- Please Select --           China  GPL34633        8  ...
# 234              Daejeon     South Korea  GPL33896        4  ...
# 235                Aichi           Japan  GPL34290        2  ...
#
#                                                PROTEIN  \
# 0                                                  NaN
# 1                                                 [PR]
# 2    [microbial community structure (p = 0.037), bu...
# 3    [p53, WT p53, p53R270H/ER, p53R172H/ER, p53 WT...
# 4    [p53, WT p53, p53R270H/ER, p53R172H/ER, p53 WT...
# ..                                                 ...
# 231  [m6A methyltransferase METTL3, METTL14, METTL3...
# 232  [m6A methyltransferase METTL3, METTL14, METTL3...
# 233  [m6A methyltransferase METTL3, METTL14, METTL3...
# 234  [anti-PD1, Ddx54, isotype control antibody, an...
# 235  [âdonât, meâ signal proteins, CD47, FOXA...
#
#                                        SIMPLE_CHEMICAL ORGANISM_SUBSTANCE  \
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# 2                                         [Firmicutes]                NaN
# 3    [4-hydroxytamoxifen, 4-OHT, 2hr, 2mM L-Glutami...              [FBS]
# 4    [4-hydroxytamoxifen, 4-OHT, 2hr, 2mM L-Glutami...              [FBS]
# ..                                                 ...                ...
# 231                                              [m6A]                NaN
# 232                                              [m6A]                NaN
# 233                                              [m6A]                NaN
# 234                                         [anti-PD1]     [Xenium Mouse]
# 235                                                NaN                NaN
#
#     CELLULAR_COMPONENT MULTI_TISSUE_STRUCTURE                          RNA  \
# 0                  NaN                    NaN                          NaN
# 1                  NaN                    NaN                          NaN
# 2                  NaN                    NaN                          NaN
# 3                  NaN                    NaN                          NaN
# 4                  NaN                    NaN                          NaN
# ..                 ...                    ...                          ...
# 231        [chromatin]                    NaN  [chromatin-associated RNAs]
# 232        [chromatin]                    NaN  [chromatin-associated RNAs]
# 233        [chromatin]                    NaN  [chromatin-associated RNAs]
# 234                NaN                    NaN                          NaN
# 235                NaN                    NaN                          NaN
#
#     PATHOLOGICAL_FORMATION IMMATERIAL_ANATOMICAL_ENTITY ANATOMICAL_SYSTEM  \
# 0                      NaN                          NaN               NaN
# 1                      NaN                          NaN               NaN
# 2                      NaN                          NaN               NaN
# 3                      NaN                          NaN               NaN
# 4                      NaN                          NaN               NaN
# ..                     ...                          ...               ...
# 231                    NaN                          NaN               NaN
# 232                    NaN                          NaN               NaN
# 233                    NaN                          NaN               NaN
# 234                    NaN                          NaN               NaN
# 235                    NaN                          NaN               NaN
#
#     AMINO_ACID
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 231        NaN
# 232        NaN
# 233        NaN
# 234        NaN
# 235        NaN
#
# [236 rows x 40 columns]

# %%
# save new geo file
new_geo.to_csv('new_geo_scispacy.csv', index=False)
